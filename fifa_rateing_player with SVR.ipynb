# %% [markdown]
# # About coder
#
# # Name :
#  fares abbas
# # From :
#  egypt
# # Studying :
#  artificial intelligence in the faculty of artificial intelligence , kafr el-sheikh unv.
# # Gmail :
#  fares.19071907@gmail.com
# # Phone num :
# (+20)1032902535

# %% [markdown]
# # fifa_rateing_player_dataset
# ********************************************

# %% [markdown]
# ********************************************

# %% [markdown]
# ************************************************

# %% [markdown]
# # loading Data

# %%
# import lib 
import pandas as pd 

# load data 
data = pd.read_csv('fifa_cleaned.csv')
df = pd.DataFrame(data)

# %%
# show head and tail of data 
df.head()
# Out:
#        id          name                       full_name  birth_date  age  \
# 0  158023      L. Messi  Lionel Andrés Messi Cuccittini  1987-06-24   31
# 1  190460    C. Eriksen    Christian  Dannemann Eriksen  1992-02-14   27
# 2  195864      P. Pogba                      Paul Pogba  1993-03-15   25
# 3  198219    L. Insigne                 Lorenzo Insigne  1991-06-04   27
# 4  201024  K. Koulibaly               Kalidou Koulibaly  1991-06-20   27
#
#    height_cm  weight_kgs  positions nationality  overall_rating  ...   LWB  \
# 0     170.18        72.1   CF,RW,ST   Argentina              94  ...  64+2
# 1     154.94        76.2  CAM,RM,CM     Denmark              88  ...  71+3
# 2     190.50        83.9     CM,CAM      France              88  ...  76+3
# 3     162.56        59.0      LW,ST       Italy              88  ...  63+3
# 4     187.96        88.9         CB     Senegal              88  ...  73+3
#
#     LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB
# ...

# %%
df.tail()
# Out:
#            id            name                         full_name  birth_date  \
# 17949  204322     R. McKenzie                    Rory  McKenzie  1993-10-07
# 17950  239762       M. Sipľak                     Michal Sipľak  1996-02-02
# 17951  235155      J. Bekkema                       Jan Bekkema  1996-04-09
# 17952  244883      A. Al Yami               Abdulrahman Al Yami  1997-06-19
# 17953  247187  Júnior Brumado  José Francisco dos Santos Júnior  1999-05-15
#
#        age  height_cm  weight_kgs  positions   nationality  overall_rating  \
# 17949   25     175.26        74.8  RM,CAM,CM      Scotland              67
# 17950   23     182.88        79.8         LB      Slovakia              59
# 17951   22     185.42        89.8         GK   Netherlands              59
# 17952   21     175.26        64.9      ST,LM  Saudi Arabia              59
# 17953   19     190.50        79.8         ST        Brazil              59
#
# ...

# %%
# show data columns name 
df.columns
# Out:
# Index(['id', 'name', 'full_name', 'birth_date', 'age', 'height_cm',
#        'weight_kgs', 'positions', 'nationality', 'overall_rating', 'potential',
#        'value_euro', 'wage_euro', 'preferred_foot',
#        'international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)',
#        'work_rate', 'body_type', 'release_clause_euro', 'club_team',
#        'club_rating', 'club_position', 'club_jersey_number', 'club_join_date',
#        'contract_end_year', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
# ...

# %% [markdown]
# # Understanding the data and visualize it

# %%
# describing data
df.describe
# Out:
# <bound method NDFrame.describe of            id            name                         full_name  birth_date  \
# 0      158023        L. Messi    Lionel Andrés Messi Cuccittini  1987-06-24
# 1      190460      C. Eriksen      Christian  Dannemann Eriksen  1992-02-14
# 2      195864        P. Pogba                        Paul Pogba  1993-03-15
# 3      198219      L. Insigne                   Lorenzo Insigne  1991-06-04
# 4      201024    K. Koulibaly                 Kalidou Koulibaly  1991-06-20
# ...       ...             ...                               ...         ...
# 17949  204322     R. McKenzie                    Rory  McKenzie  1993-10-07
# 17950  239762       M. Sipľak                     Michal Sipľak  1996-02-02
# 17951  235155      J. Bekkema                       Jan Bekkema  1996-04-09
# 17952  244883      A. Al Yami               Abdulrahman Al Yami  1997-06-19
# 17953  247187  Júnior Brumado  José Francisco dos Santos Júnior  1999-05-15
#
# ...

# %%
# info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 92 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             17954 non-null  int64
#  1   name                           17954 non-null  object
#  2   full_name                      17954 non-null  object
#  3   birth_date                     17954 non-null  object
#  4   age                            17954 non-null  int64
#  5   height_cm                      17954 non-null  float64
#  6   weight_kgs                     17954 non-null  float64
#  7   positions                      17954 non-null  object
#  8   nationality                    17954 non-null  object
#  9   overall_rating                 17954 non-null  int64
#  10  potential                      17954 non-null  int64
#  11  value_euro                     17699 non-null  float64
# ...

# %%
# nulls value
df.isnull().sum()
# Out:
# id               0
# name             0
# full_name        0
# birth_date       0
# age              0
#               ...
# LB            2065
# LCB           2065
# CB            2065
# RCB           2065
# RB            2065
# Length: 92, dtype: int64

# %%
# num of nationality
df.groupby(['nationality']).count()['id']
# Out:
# nationality
# Afghanistan      3
# Albania         42
# Algeria         60
# Andorra          1
# Angola          13
#               ...
# Vietnam          1
# Wales          130
# Yemen            1
# Zambia          10
# Zimbabwe        13
# Name: id, Length: 160, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sb
# age
figure(figsize=(10, 10))
sb.set_style("darkgrid")
plt.xticks(rotation=70)
sb.countplot(x='age', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
# rating 
figure(figsize=(15, 15))
sb.set_style("darkgrid")
plt.xticks(rotation=70)
sb.countplot(x='overall_rating', data=df)
# Out:
# <AxesSubplot:xlabel='overall_rating', ylabel='count'>

# %%
# nationality
count=df['nationality'].value_counts()
the_best_10=count[0:10]
the_10=the_best_10.to_frame((10,10))
the_10.plot.bar()
# Out:
# <AxesSubplot:>

# %%
count=df['overall_rating'].value_counts()
the_best_10=count[0:10]
the_10=the_best_10.to_frame((10,10))
the_10.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# dist of label
plt.figure(figsize=(10,6))
plt.title("Before transformation of overall_rating")
dist = sb.distplot(df['overall_rating'],norm_hist=False)
plt.grid()
# Out:
# C:\Users\fares abbas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # data prep

# %%
# corr
plt.figure(figsize=(20,20))
correlation = df.corr()
sb.heatmap(correlation, mask = correlation <0.8, linewidth=1, cmap='Blues')
plt.grid()

# %%
new_data = df.drop(['release_clause_euro', 'dribbling' ,'short_passing','sliding_tackle', 'GK_handling', 'GK_kicking', 'GK_positioning', 'GK_reflexes','national_team','national_rating','national_team_position','national_jersey_number','id','name','full_name','birth_date','nationality','body_type','club_team','positions','club_position','tags','traits'], axis=1)

# %%
new_data
# Out:
#        age  height_cm  weight_kgs  overall_rating  potential   value_euro  \
# 0       31     170.18        72.1              94         94  110500000.0
# 1       27     154.94        76.2              88         89   69500000.0
# 2       25     190.50        83.9              88         91   73000000.0
# 3       27     162.56        59.0              88         88   62000000.0
# 4       27     187.96        88.9              88         91   60000000.0
# ...    ...        ...         ...             ...        ...          ...
# 17949   25     175.26        74.8              67         70     975000.0
# 17950   23     182.88        79.8              59         67     190000.0
# 17951   22     185.42        89.8              59         67     170000.0
# 17952   21     175.26        64.9              59         71     280000.0
# 17953   19     190.50        79.8              59         75     325000.0
#
#        wage_euro preferred_foot  international_reputation(1-5)  \
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            17954 non-null  int64
#  1   height_cm                      17954 non-null  float64
#  2   weight_kgs                     17954 non-null  float64
#  3   overall_rating                 17954 non-null  int64
#  4   potential                      17954 non-null  int64
#  5   value_euro                     17699 non-null  float64
#  6   wage_euro                      17708 non-null  float64
#  7   preferred_foot                 17954 non-null  object
#  8   international_reputation(1-5)  17954 non-null  int64
#  9   weak_foot(1-5)                 17954 non-null  int64
#  10  skill_moves(1-5)               17954 non-null  int64
#  11  work_rate                      17954 non-null  object
# ...

# %%
objList = new_data.select_dtypes(include = "object").columns
print (objList)
# Out:
# Index(['preferred_foot', 'work_rate', 'club_join_date', 'contract_end_year',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB'],
#       dtype='object')

# %%
#Label Encoding for object to numeric conversion
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feat in objList:
    new_data[feat] = le.fit_transform(new_data[feat].astype(str))

print (new_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            17954 non-null  int64
#  1   height_cm                      17954 non-null  float64
#  2   weight_kgs                     17954 non-null  float64
#  3   overall_rating                 17954 non-null  int64
#  4   potential                      17954 non-null  int64
#  5   value_euro                     17699 non-null  float64
#  6   wage_euro                      17708 non-null  float64
#  7   preferred_foot                 17954 non-null  int32
#  8   international_reputation(1-5)  17954 non-null  int64
#  9   weak_foot(1-5)                 17954 non-null  int64
#  10  skill_moves(1-5)               17954 non-null  int64
#  11  work_rate                      17954 non-null  int32
# ...

# %%
# X , y data
X = new_data.drop(['overall_rating'],axis=1)
y = new_data.overall_rating

# %%
#Import Libraries
from sklearn.impute import SimpleImputer
import numpy as np
#----------------------------------------------------

#----------------------------------------------------
# Cleaning data

'''
impute.SimpleImputer(missing_values=nan, strategy='mean’, fill_value=None, verbose=0, copy=True)
'''


ImputedModule = SimpleImputer(missing_values = np.nan, strategy ='mean')
ImputedX = ImputedModule.fit(X)
X = ImputedX.transform(X)


#X Data
#print('X Data is \n' , X[:10])

#y Data
#print('y Data is \n' , y[:10])

# %%
#Import Libraries
from sklearn.preprocessing import StandardScaler
#----------------------------------------------------

#----------------------------------------------------
#Standard Scaler for Data

scaler = StandardScaler(copy=True, with_mean=True, with_std=True)
X = scaler.fit_transform(X)

#showing data
#print('X \n' , X[:10])
#print('y \n' , y[:10])

# %%
X
# Out:
# array([[-0.45841858, -0.5577244 , -0.55300546, ..., -0.36231552,
#         -0.36231552, -0.35273327],
#        [-0.45769433, -0.55692514, -0.55181345, ..., -0.36122477,
#         -0.36122477, -0.35146752],
#        [-0.45800311, -0.55648424, -0.55167138, ..., -0.3602747 ,
#         -0.3602747 , -0.35093609],
#        ...,
#        [ 0.40792191,  0.70518667,  0.86359995, ...,  1.19827501,
#          1.19827501,  1.22965672],
#        [ 0.04283562,  0.16621242,  0.06756005, ..., -0.31080243,
#         -0.31080243, -0.26466605],
#        [-0.06808135,  0.1201501 ,  0.10453678, ..., -0.25808482,
#         -0.25808482, -0.26847115]])

# %%
#Import Libraries
from sklearn.model_selection import train_test_split
#----------------------------------------------------

#----------------------------------------------------
#Splitting data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=44, shuffle =True)

#Splitted Data
#print('X_train shape is ' , X_train.shape)
#print('X_test shape is ' , X_test.shape)
#print('y_train shape is ' , y_train.shape)
#print('y_test shape is ' , y_test.shape)

# %%
#Import Libraries
from sklearn.svm import SVR

'''
sklearn.svm.SVR(kernel=’rbf’, degree=3, gamma=’auto_deprecated’, coef0=0.0, tol=0.001,
                C=1.0, epsilon=0.1, shrinking=True, cache_size=200, verbose=False,max_iter=-1)
'''

SVRModel = SVR(C = 1.0 ,epsilon=0.01,kernel = 'rbf') # it also can be : linear, poly, rbf, sigmoid, precomputed
SVRModel.fit(X_train, y_train)

#Calculating Details
print('SVRModel Train Score is : ' , SVRModel.score(X_train, y_train))
print('SVRModel Test Score is : ' , SVRModel.score(X_test, y_test))
#print('----------------------------------------------------')

#Calculating Prediction
y_pred = SVRModel.predict(X_test)
# Out:
# SVRModel Train Score is :  0.8992759358752466
# SVRModel Test Score is :  0.8992593324069574

# %%
print('Predicted Value for SVRModel is : ' , y_pred[:10])
# Out:
# Predicted Value for SVRModel is :  [74.81877307 68.11076653 67.52179079 65.79161744 58.19931422 66.18973735
#  57.65192315 74.1026011  72.68076357 55.83281805]

# %%
y_test[:10]
# Out:
# 17498    79
# 2297     67
# 14448    70
# 14669    71
# 6637     58
# 10977    66
# 6042     57
# 16622    75
# 841      73
# 5687     55
# Name: overall_rating, dtype: int64
